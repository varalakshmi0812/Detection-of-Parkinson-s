# %% [markdown]
# <a href="https://colab.research.google.com/github/varalakshmi0812/Detection-of-Parkinson-s/blob/main/Parkinsons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INSTALLING XGBOOST**
#
#  Implementation of gradient boosted decision trees designed for speed and performance

# %%
pip install xgboost

# %% [markdown]
# **INSTALLING REQUIRED** **PACKAGES**

# %%
import numpy as numpy
import pandas as pd

# %% [markdown]
# **READING THE DATASET**

# %%
data=pd.read_csv("https://raw.githubusercontent.com/chaitanyabaranwal/ParkinsonAnalysis/master/parkinsons.csv")

# %%
data.head(20)
# Out:
#               name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0   phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1   phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2   phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3   phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4   phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5   phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6   phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7   phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8   phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9   phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10  phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %% [markdown]
# **SEPERATING FEATURES AND LABELS**

# %%
features=data.loc[:,data.columns!='status'].values[:,1:]
labels=data.loc[:,'status'].values

# %%
print(labels[labels==1].shape[0],labels[labels==0].shape[0])
# Out:
# 147 48

# %% [markdown]
# **FLATTEN THE VALUES**

# %%
from sklearn.preprocessing import  MinMaxScaler
obj=MinMaxScaler((-1,1))
x=obj.fit_transform(features)
y=labels

# %% [markdown]
# **DIVIDING INTO TESTING AND TRAINING DATA**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %% [markdown]
# **FEEDING THE MODE**L

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier()

# %% [markdown]
# **FIND ACCURACY BASING ON THE PREDICTIONS**

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 94.87179487179486
